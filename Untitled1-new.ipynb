# %%
# ============================================================
# Sign Language Training Pipeline (LOCAL)
# ✅ Group split BEFORE augmentation (prevents leakage)
# ✅ Optional: fixed length sampling + keypoint normalization (recommended)
# ✅ Better "Unknown" rule (top1 + margin)
# ============================================================

import os, re, tempfile, pickle, math, json
from collections import Counter

import numpy as np
import cv2
import mediapipe as mp

from moviepy.editor import VideoFileClip, vfx

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Masking, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
VIDEO_FOLDER = "./data/model_1_videos"          # LOCAL videos
KEYPOINTS_FOLDER = "./data/model_1_new_keypoints"

# %%
# ----------------------------
# CONFIG
# ----------------------------

os.makedirs(KEYPOINTS_FOLDER, exist_ok=True)

# augmentation settings (applied ONLY on TRAIN split)
AUGMENT_FOR_LESS_THAN = 3      # if class has < 3 ORIGINAL videos -> augment
AUG_CLIPS_PER_VIDEO = 4        # number of augmentations (excluding original)
TARGET_SAMPLES_PER_CLASS = 8   # after augmentation/dup, aim for ~ this many
DUPLICATE_TO_REACH = True

# training
MAX_EPOCHS = 50
BATCH_SIZE = 4
PATIENCE = 6
RANDOM_SEED = 42

# sequence processing
FEAT_DIM = 126
FIXED_LEN = 100  # <<< recommended fixed length (stabilizes timing). Change to 81/120 if you want.

# prediction unknown logic
PRED_THRESHOLD = 0.60
PRED_MARGIN = 0.15

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# ----------------------------
# LABEL EXTRACTION
# ----------------------------
def clean_label_from_filename(filename: str) -> str:
    base = os.path.basename(filename)
    part = base.split('-', 1)[0]
    part = re.sub(r'\(.*?\)', '', part)  # remove (SS) etc
    part = re.sub(r'[^A-Za-z0-9ÄÖÅäöåÜüÉéĄąŁłŚśĆćŻżŹź\- ]+', '', part)
    return part.strip().upper()

# ----------------------------
# AUGMENTATION
# NOTE: For sign language, mirror can change meaning.
# ----------------------------
def write_clip_to_tmp(clip: VideoFileClip, path: str) -> str:
    clip.write_videofile(path, codec="libx264", audio=False, verbose=False, logger=None)
    return path

def generate_augmented_temp_paths(video_path: str):
    clip = VideoFileClip(video_path)
    tmp_dir = tempfile.gettempdir()
    base = os.path.splitext(os.path.basename(video_path))[0]

    paths = []

    # original
    orig = os.path.join(tmp_dir, f"{base}_orig.mp4")
    write_clip_to_tmp(clip, orig)
    paths.append(orig)

    # augmentations: brightness + speed (safe-ish)
    aug_funcs = [
        lambda c: c.fx(vfx.colorx, 1.25),
        lambda c: c.fx(vfx.colorx, 0.75),
        lambda c: c.fx(vfx.speedx, 1.2),
        lambda c: c.fx(vfx.speedx, 0.85),
    ]

    for i in range(AUG_CLIPS_PER_VIDEO):
        aug = aug_funcs[i % len(aug_funcs)](clip)
        p = os.path.join(tmp_dir, f"{base}_aug_{i}.mp4")
        write_clip_to_tmp(aug, p)
        paths.append(p)

    clip.close()
    return paths

# ----------------------------
# MEDIAPIPE KEYPOINT EXTRACTION (consistent left/right)
# ----------------------------
mp_hands = mp.solutions.hands

def extract_hand_keypoints_consistent(video_path, max_frames=None):
    cap = cv2.VideoCapture(video_path)
    seq = []

    with mp_hands.Hands(
        static_image_mode=False,
        max_num_hands=2,
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5
    ) as hands:
        frame_idx = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            frame_idx += 1
            if max_frames and frame_idx > max_frames:
                break

            image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = hands.process(image_rgb)

            left = np.zeros((21, 3), dtype=np.float32)
            right = np.zeros((21, 3), dtype=np.float32)

            if results.multi_hand_landmarks and results.multi_handedness:
                for lm, handedness in zip(results.multi_hand_landmarks, results.multi_handedness):
                    coords = np.array([[p.x, p.y, p.z] for p in lm.landmark], dtype=np.float32)
                    if handedness.classification[0].label.lower().startswith("left"):
                        left = coords
                    else:
                        right = coords

            seq.append(np.concatenate([left.flatten(), right.flatten()]))

    cap.release()
    return np.array(seq, dtype=np.float32)  # [T,126] (T variable)

# ----------------------------
# KEYPOINT NORMALIZATION (recommended)
# - wrist-center per hand (landmark 0)
# - scale by wrist->middle_mcp (landmark 9) if possible
# ----------------------------
def normalize_seq(seq_126):
    # seq_126: [T, 126]
    if seq_126.shape[0] == 0:
        return seq_126

    seq = seq_126.reshape((-1, 2, 21, 3))  # [T, hand, lm, xyz]
    out = np.zeros_like(seq, dtype=np.float32)

    for h in range(2):
        hand = seq[:, h, :, :]  # [T,21,3]

        wrist = hand[:, 0:1, :]  # [T,1,3]
        hand0 = hand - wrist

        scale = np.linalg.norm(hand0[:, 9, :], axis=1, keepdims=True)  # [T,1]
        scale = np.clip(scale, 1e-6, None)

        handn = hand0 / scale[:, None, :]  # [T,21,3]
        out[:, h, :, :] = handn

    return out.reshape((-1, 126)).astype(np.float32)

# ----------------------------
# FIXED LENGTH SAMPLING
# ----------------------------
def to_fixed_length(seq, T=FIXED_LEN):
    # seq: [t,126]
    t = seq.shape[0]
    if t == 0:
        return np.zeros((T, FEAT_DIM), dtype=np.float32)
    if t == T:
        return seq.astype(np.float32)
    if t > T:
        idx = np.linspace(0, t - 1, T).astype(int)
        return seq[idx].astype(np.float32)
    # t < T
    pad = np.zeros((T - t, FEAT_DIM), dtype=np.float32)
    return np.concatenate([seq.astype(np.float32), pad], axis=0)

# ----------------------------
# STEP A: LIST ORIGINALS + GROUP SPLIT FIRST
# ----------------------------
video_files = sorted([f for f in os.listdir(VIDEO_FOLDER)
                      if f.lower().endswith(('.mp4', '.avi', '.mov', '.mkv'))])

orig_items = [(os.path.join(VIDEO_FOLDER, f), clean_label_from_filename(f)) for f in video_files]
orig_labels = [lab for _, lab in orig_items]
counts = Counter(orig_labels)

if len(orig_items) == 0:
    raise RuntimeError(f"No videos found in {VIDEO_FOLDER}")

# stratify only if every class has >= 2 originals
can_stratify = min(counts.values()) >= 2

train_items, val_items = train_test_split(
    orig_items,
    test_size=0.2,
    random_state=RANDOM_SEED,
    stratify=orig_labels if can_stratify else None
)

print("Original train videos:", len(train_items))
print("Original val videos:", len(val_items))
print("Train label counts:", Counter([y for _, y in train_items]))
print("Val label counts:", Counter([y for _, y in val_items]))

# ----------------------------
# STEP B: BUILD PROCESS LISTS
# - augment only train
# - no augmentation in validation
# ----------------------------
to_process_train = []
for path, label in train_items:
    if counts[label] < AUGMENT_FOR_LESS_THAN:
        tmp_paths = generate_augmented_temp_paths(path)
        for p in tmp_paths:
            to_process_train.append((p, label))

        if DUPLICATE_TO_REACH and len(tmp_paths) < TARGET_SAMPLES_PER_CLASS:
            reps = math.ceil(TARGET_SAMPLES_PER_CLASS / len(tmp_paths))
            for _ in range(reps - 1):
                for p in tmp_paths:
                    to_process_train.append((p, label))
    else:
        to_process_train.append((path, label))

to_process_val = [(path, label) for path, label in val_items]

print("Train clips to process:", len(to_process_train))
print("Val clips to process:", len(to_process_val))

# ----------------------------
# STEP C: EXTRACT + SAVE KEYPOINTS
# (separate train/val prefixes)
# ----------------------------
def process_and_save(to_process, split_tag):
    saved = []
    for i, (path, label) in enumerate(to_process):
        base = os.path.splitext(os.path.basename(path))[0]
        safe_base = re.sub(r'[^A-Za-z0-9_.\-]+', '_', base)
        npy_name = f"{split_tag}__{label}__{safe_base}.npy"
        npy_path = os.path.join(KEYPOINTS_FOLDER, npy_name)

        if os.path.exists(npy_path) and os.path.getsize(npy_path) > 0:
            saved.append((npy_path, label))
            continue

        print(f"[{split_tag} {i+1}/{len(to_process)}] {path}")
        seq = extract_hand_keypoints_consistent(path)

        if seq.shape[0] == 0:
            print("  -> no keypoints detected, skipping")
            continue

        seq = normalize_seq(seq)
        seq = to_fixed_length(seq, FIXED_LEN)

        np.save(npy_path, seq.astype(np.float32))
        saved.append((npy_path, label))
    return saved

saved_train = process_and_save(to_process_train, "train")
saved_val = process_and_save(to_process_val, "val")

print("Saved train keypoints:", len(saved_train))
print("Saved val keypoints:", len(saved_val))

if len(saved_train) == 0 or len(saved_val) == 0:
    raise RuntimeError("Not enough extracted sequences for training/validation. Check videos/keypoints.")

# ----------------------------
# STEP D: BUILD X_train, y_train, X_val, y_val
# ----------------------------
X_train_list, y_train_list = [], []
for p, label in saved_train:
    X_train_list.append(np.load(p).astype(np.float32))
    y_train_list.append(label)

X_val_list, y_val_list = [], []
for p, label in saved_val:
    X_val_list.append(np.load(p).astype(np.float32))
    y_val_list.append(label)

# Encode labels (fit on TRAIN labels only)
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train_list)
y_val_enc = le.transform(y_val_list)

num_classes = len(le.classes_)
print("Classes:", list(le.classes_))

X_train = np.stack(X_train_list, axis=0)  # [N,T,126]
X_val = np.stack(X_val_list, axis=0)

y_train = to_categorical(y_train_enc, num_classes=num_classes).astype(np.float32)
y_val = to_categorical(y_val_enc, num_classes=num_classes).astype(np.float32)

print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_val:", X_val.shape, "y_val:", y_val.shape)

# ----------------------------
# STEP E: MODEL
# ----------------------------
model = Sequential([
    Masking(mask_value=0.0, input_shape=(FIXED_LEN, FEAT_DIM)),
    LSTM(64),
    Dropout(0.3),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax"),
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()

callbacks = [
    EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True, verbose=1),
    ModelCheckpoint("best_sign_model_tf213_new.h5", monitor="val_loss", save_best_only=True, verbose=1),
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=MAX_EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    shuffle=True,
    verbose=1
)

# ----------------------------
# STEP F: SAVE MODEL + ENCODER + META
# ----------------------------
model.save("sign_model_tf213_new.h5")
with open("label_encoder_new.pkl", "wb") as f:
    pickle.dump(le, f)

meta = {
    "fixed_len": FIXED_LEN,
    "feat_dim": FEAT_DIM,
    "pred_threshold": PRED_THRESHOLD,
    "pred_margin": PRED_MARGIN
}
with open("model_meta.json", "w", encoding="utf-8") as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

print("Saved: sign_model_tf213_new.h5, label_encoder_new.pkl, model_meta.json")

# ----------------------------
# STEP G: PREDICT FUNCTION
# ----------------------------
def predict_video(video_path, threshold=PRED_THRESHOLD, margin=PRED_MARGIN):
    seq = extract_hand_keypoints_consistent(video_path)
    if seq.shape[0] == 0:
        return ("NoKeypoints", 0.0)

    seq = normalize_seq(seq)
    seq = to_fixed_length(seq, FIXED_LEN)

    inp = np.expand_dims(seq, axis=0).astype(np.float32)
    probs = model.predict(inp, verbose=0)[0]

    top1 = int(np.argmax(probs))
    top1_conf = float(probs[top1])

    # top2
    top2 = int(np.argsort(probs)[-2])
    top2_conf = float(probs[top2])

    label = le.inverse_transform([top1])[0]

    if (top1_conf < threshold) or ((top1_conf - top2_conf) < margin):
        return ("Unknown", top1_conf)

    return (label, top1_conf)

# Example:
# print(predict_video("./some_test_video.mp4"))
# Out:
# Original train videos: 35
# Original val videos: 9
# Train label counts: Counter({'AAVIKKO': 6, 'AAMUPÄIVÄ': 5, 'AAMU': 5, 'AALTO': 4, 'ACCEPT': 4, 'AJAA ASIAA': 4, 'AJATELLA': 3, 'YLÄKERTA': 2, 'AVOIN': 2})
# Val label counts: Counter({'AJATELLA': 1, 'YLÄKERTA': 1, 'ACCEPT': 1, 'AVOIN': 1, 'AAMU': 1, 'AAVIKKO': 1, 'AALTO': 1, 'AJAA ASIAA': 1, 'AAMUPÄIVÄ': 1})
# Train clips to process: 35
# Val clips to process: 9
# [train 13/35] ./data/model_1_videos\AALTO - 5.mp4
# [train 15/35] ./data/model_1_videos\YLÄKERTA-4.mp4
# [val 1/9] ./data/model_1_videos\AJATELLA-1.mp4
# [val 2/9] ./data/model_1_videos\YLÄKERTA-3.mp4
# Saved train keypoints: 35
# Saved val keypoints: 9
# Classes: ['AALTO', 'AAMU', 'AAMUPÄIVÄ', 'AAVIKKO', 'ACCEPT', 'AJAA ASIAA', 'AJATELLA', 'AVOIN', 'YLÄKERTA']
# X_train: (35, 100, 126) y_train: (35, 9)
# X_val: (9, 100, 126) y_val: (9, 9)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking_3 (Masking)         (None, 100, 126)          0
#
#  lstm_3 (LSTM)               (None, 64)                48896
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 9)                 297
#
# =================================================================
# Total params: 51273 (200.29 KB)
# Trainable params: 51273 (200.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 9/9 [==============================] - ETA: 0s - loss: 2.3059 - accuracy: 0.1143
# Epoch 1: val_loss improved from inf to 2.10455, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 10s 369ms/step - loss: 2.3059 - accuracy: 0.1143 - val_loss: 2.1046 - val_accuracy: 0.1111
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 2.0245 - accuracy: 0.1714
# Epoch 2: val_loss improved from 2.10455 to 1.94860, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 49ms/step - loss: 2.0245 - accuracy: 0.1714 - val_loss: 1.9486 - val_accuracy: 0.4444
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 1.8147 - accuracy: 0.4000
# Epoch 3: val_loss improved from 1.94860 to 1.80859, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.8147 - accuracy: 0.4000 - val_loss: 1.8086 - val_accuracy: 0.4444
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 1.4992 - accuracy: 0.7143
# Epoch 4: val_loss improved from 1.80859 to 1.69415, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 53ms/step - loss: 1.4992 - accuracy: 0.7143 - val_loss: 1.6941 - val_accuracy: 0.4444
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 1.4018 - accuracy: 0.5429
# Epoch 5: val_loss improved from 1.69415 to 1.59164, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 45ms/step - loss: 1.4018 - accuracy: 0.5429 - val_loss: 1.5916 - val_accuracy: 0.4444
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2842 - accuracy: 0.7143
# Epoch 6: val_loss improved from 1.59164 to 1.47266, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 58ms/step - loss: 1.2842 - accuracy: 0.7143 - val_loss: 1.4727 - val_accuracy: 0.5556
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 1.1628 - accuracy: 0.6286
# Epoch 7: val_loss improved from 1.47266 to 1.33887, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 1s 91ms/step - loss: 1.1628 - accuracy: 0.6286 - val_loss: 1.3389 - val_accuracy: 0.5556
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 1.0111 - accuracy: 0.7143
# Epoch 8: val_loss improved from 1.33887 to 1.23876, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0111 - accuracy: 0.7143 - val_loss: 1.2388 - val_accuracy: 0.7778
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 0.8548 - accuracy: 0.8000
# Epoch 9: val_loss improved from 1.23876 to 1.14108, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 45ms/step - loss: 0.8548 - accuracy: 0.8000 - val_loss: 1.1411 - val_accuracy: 0.7778
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 0.8066 - accuracy: 0.7714
# Epoch 10: val_loss improved from 1.14108 to 1.09817, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 0.8066 - accuracy: 0.7714 - val_loss: 1.0982 - val_accuracy: 0.6667
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 0.7784 - accuracy: 0.7714
# Epoch 11: val_loss improved from 1.09817 to 0.93127, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 45ms/step - loss: 0.7784 - accuracy: 0.7714 - val_loss: 0.9313 - val_accuracy: 0.7778
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 0.5841 - accuracy: 0.9143
# Epoch 12: val_loss improved from 0.93127 to 0.85089, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 46ms/step - loss: 0.5841 - accuracy: 0.9143 - val_loss: 0.8509 - val_accuracy: 0.7778
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 0.5866 - accuracy: 0.8857
# Epoch 13: val_loss improved from 0.85089 to 0.82144, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 47ms/step - loss: 0.5866 - accuracy: 0.8857 - val_loss: 0.8214 - val_accuracy: 0.7778
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 0.4734 - accuracy: 0.9429
# Epoch 14: val_loss improved from 0.82144 to 0.77565, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 44ms/step - loss: 0.4734 - accuracy: 0.9429 - val_loss: 0.7756 - val_accuracy: 0.7778
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 0.4122 - accuracy: 0.9714
# Epoch 15: val_loss improved from 0.77565 to 0.74814, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 44ms/step - loss: 0.4122 - accuracy: 0.9714 - val_loss: 0.7481 - val_accuracy: 0.7778
# Epoch 16/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 0.9143
# Epoch 16: val_loss improved from 0.74814 to 0.71563, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 43ms/step - loss: 0.3775 - accuracy: 0.9143 - val_loss: 0.7156 - val_accuracy: 0.7778
# Epoch 17/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.8857
# Epoch 17: val_loss did not improve from 0.71563
# 9/9 [==============================] - 0s 40ms/step - loss: 0.3772 - accuracy: 0.8857 - val_loss: 0.7632 - val_accuracy: 0.7778
# Epoch 18/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8857
# Epoch 18: val_loss did not improve from 0.71563
# 9/9 [==============================] - 0s 42ms/step - loss: 0.3178 - accuracy: 0.8857 - val_loss: 0.7255 - val_accuracy: 0.8889
# Epoch 19/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9714
# Epoch 19: val_loss improved from 0.71563 to 0.67393, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 0s 45ms/step - loss: 0.2443 - accuracy: 0.9714 - val_loss: 0.6739 - val_accuracy: 0.8889
# Epoch 20/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9714
# Epoch 20: val_loss improved from 0.67393 to 0.65160, saving model to best_sign_model_tf213_new.h5
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1755 - accuracy: 0.9714 - val_loss: 0.6516 - val_accuracy: 0.8889
# Epoch 21/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.9714
# Epoch 21: val_loss did not improve from 0.65160
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2451 - accuracy: 0.9714 - val_loss: 0.7145 - val_accuracy: 0.7778
# Epoch 22/50
# 9/9 [==============================] - ETA: 0s - loss: 0.3580 - accuracy: 0.9143
# Epoch 22: val_loss did not improve from 0.65160
# 9/9 [==============================] - 0s 49ms/step - loss: 0.3580 - accuracy: 0.9143 - val_loss: 0.7856 - val_accuracy: 0.7778
# Epoch 23/50
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2500 - accuracy: 0.9375
# Epoch 23: val_loss did not improve from 0.65160
# 9/9 [==============================] - 0s 51ms/step - loss: 0.2367 - accuracy: 0.9429 - val_loss: 0.7704 - val_accuracy: 0.8889
# Epoch 24/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1824 - accuracy: 0.9429
# Epoch 24: val_loss did not improve from 0.65160
# 9/9 [==============================] - 0s 48ms/step - loss: 0.1824 - accuracy: 0.9429 - val_loss: 0.7692 - val_accuracy: 0.8889
# Epoch 25/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.65160
# 9/9 [==============================] - 0s 48ms/step - loss: 0.1369 - accuracy: 1.0000 - val_loss: 0.7002 - val_accuracy: 0.8889
# Epoch 26/50
# 9/9 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9714Restoring model weights from the end of the best epoch: 20.
#
# Epoch 26: val_loss did not improve from 0.65160
# 9/9 [==============================] - 1s 88ms/step - loss: 0.2832 - accuracy: 0.9714 - val_loss: 0.6857 - val_accuracy: 0.8889
# Epoch 26: early stopping
# Saved: sign_model_tf213_new.h5, label_encoder_new.pkl, model_meta.json

# %%
test_video = "./test_videos/WIN_20260324_14_51_44_Pro.mp4"
label, conf = predict_video(test_video, threshold=0.5)
print(f"Prediction: {label} ({conf*100:.2f}%)")
# Out:
# Prediction: AJAA ASIAA (53.52%)

# %%
# import cv2
# import mediapipe as mp

# # --------- Set paths ----------
# INPUT_VIDEO = "./test_videos/AJATELLA-4.mp4"              # change this
# OUTPUT_VIDEO = "./test_videos/test_with_points_AJATELLA-4 .mp4" # output video

# mp_hands = mp.solutions.hands
# mp_draw = mp.solutions.drawing_utils

# cap = cv2.VideoCapture(INPUT_VIDEO)
# if not cap.isOpened():
#     raise FileNotFoundError(f"Could not open: {INPUT_VIDEO}")

# fps = cap.get(cv2.CAP_PROP_FPS) or 30
# w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# fourcc = cv2.VideoWriter_fourcc(*"mp4v")
# out = cv2.VideoWriter(OUTPUT_VIDEO, fourcc, fps, (w, h))

# with mp_hands.Hands(
#     static_image_mode=False,
#     max_num_hands=2,
#     min_detection_confidence=0.5,
#     min_tracking_confidence=0.5
# ) as hands:
#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             break

#         rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         results = hands.process(rgb)

#         if results.multi_hand_landmarks:
#             for hand_landmarks in results.multi_hand_landmarks:
#                 mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

#         out.write(frame)

# cap.release()
# out.release()

# print("✅ Saved:", OUTPUT_VIDEO)
# Out:
# ✅ Saved: ./test_videos/test_with_points_AJATELLA-4 .mp4
